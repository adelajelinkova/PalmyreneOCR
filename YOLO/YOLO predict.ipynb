# %% [markdown]
# **connect to drive**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# **imports**

# %%
import os
HOME = os.getcwd()
print(HOME)

# !pip install ultralytics==8.0.28

from IPython import display
import ultralytics
from ultralytics import YOLO
from IPython.display import display, Image
# Out:
# /content
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 272.6/272.6 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.5/257.5 kB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# **multi-class segmentation**
# optional argument: imgsz=1280

# %%
# !yolo source=/content/drive/Shareddrives/IGA_A2_2023_Palmyrene/Data/Muzejni_foto/Virtual_museum_of_Syria/fragment10.PNG task=segment conf=0.4 mode=predict save=true save_txt=true model=/content/drive/Shareddrives/IGA_A2_2023_Palmyrene/Results/multiclass_v21_best.pt
# Out:
# 2024-01-31 08:06:28.599968: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-31 08:06:28.600081: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-31 08:06:28.601968: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-31 08:06:30.149289: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU
# YOLOv8s-seg summary (fused): 195 layers, 11789662 parameters, 0 gradients, 42.5 GFLOPs
#
# ...

# %% [markdown]
# **single-class segmentation**

# %%
# !yolo source=/content/drive/Shareddrives/IGA_A2_2023_Palmyrene/Data/Muzejni_foto/Virtual_museum_of_Syria/fragment10.PNG task=segment conf=0.4 mode=predict save=true save_txt=true model=/content/drive/Shareddrives/IGA_A2_2023_Palmyrene/Results/singleclass_v22_best.pt
# Out:
# 2024-01-31 08:08:11.433719: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-31 08:08:11.433802: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-31 08:08:11.435524: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-31 08:08:12.967286: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.28 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU
# YOLOv8s-seg summary (fused): 195 layers, 11780374 parameters, 0 gradients, 42.4 GFLOPs
#
# ...

# %%
# list of sources for the test:
# source=/content/drive/Shareddrives/IGA_A2_2023_Palmyrene/Data/Muzejni_foto/Musée_du_Louvre/nápisy/08-516088.jpg
# source=/content/drive/Shareddrives/IGA_A2_2023_Palmyrene/Data/Muzejni_foto/Getty_Villa_Museum/79_2200.jpg
# source=/content/drive/Shareddrives/IGA_A2_2023_Palmyrene/Data/Muzejni_foto/Virtual_museum_of_Syria/fragment10.PNG
# source=/content/drive/Shareddrives/IGA_A2_2023_Palmyrene/Data/Muzejni_foto/MET_Museum/1929-right.jpg
# source=/content/drive/Shareddrives/IGA_A2_2023_Palmyrene/Data/Muzejni_foto/Brittish_Museum/1097452001.jpg
# source=/content/drive/Shareddrives/IGA_A2_2023_Palmyrene/Data/Muzejni_foto/MET_Museum/DP-15732-011.jpg
